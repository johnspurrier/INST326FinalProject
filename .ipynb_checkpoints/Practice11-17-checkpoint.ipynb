# %% [markdown]
# A DataFrame is a two dimensional data with an index, columns are a series (each has a label and position), each row has a label (from the index) and a position.

# %%
import pandas as pd

df = pd.read_csv("DisneylandReviews.csv", engine = 'python')
df.head()
# Out:
#    Review_ID  Rating Year_Month     Reviewer_Location  \
# 0  670772142       4     2019-4             Australia
# 1  670682799       4     2019-5           Philippines
# 2  670623270       4     2019-4  United Arab Emirates
# 3  670607911       4     2019-4             Australia
# 4  670607296       4     2019-4        United Kingdom
#
#                                          Review_Text               Branch
# 0  If you've ever been to Disneyland anywhere you...  Disneyland_HongKong
# 1  Its been a while since d last time we visit HK...  Disneyland_HongKong
# 2  Thanks God it wasn   t too hot or too humid wh...  Disneyland_HongKong
# 3  HK Disneyland is a great compact park. Unfortu...  Disneyland_HongKong
# 4  the location is not in the city, took around 1...  Disneyland_HongKong

# %%
df[(df["Rating"] > 4) & (df["Year_Month"] >= "2019-4")]
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 6      670585330       5     2019-4             India
# 10     670443403       5     2019-4     United States
# 11     670435886       5     2019-4            Canada
# 13     670324965       5     2019-4       Philippines
# 20     670030877       5     2019-4    United Kingdom
# ...          ...     ...        ...               ...
# 42649    2174555       5    missing    United Kingdom
# 42650    1879452       5    missing    United Kingdom
# 42651    1765031       5    missing    United Kingdom
# 42652    1659553       5    missing            Canada
# 42653    1645894       5    missing      South Africa
#
#                                              Review_Text               Branch
# 6      Great place! Your day will go by and you won't...  Disneyland_HongKong
# 10     Disneyland never cease to amaze me! I've been ...  Disneyland_HongKong
# 11     We spent the day here with our grown kids and ...  Disneyland_HongKong
# ...

# %% [markdown]
# For the boolean indexing I chose to pull all of the reviews that were rated higher than 4 and came during of after April of 2019 by using the & operator. This works because

# %% [markdown]
# To select a column from a DataFrame using the column label, you have to use the [] with the label of the column in it. You can do this with as many columns as you want, they just need to be separated by commas.

# %%
df[["Rating", "Year_Month", "Reviewer_Location"]]
# Out:
#        Rating Year_Month     Reviewer_Location
# 0           4     2019-4             Australia
# 1           4     2019-5           Philippines
# 2           4     2019-4  United Arab Emirates
# 3           4     2019-4             Australia
# 4           4     2019-4        United Kingdom
# ...       ...        ...                   ...
# 42651       5    missing        United Kingdom
# 42652       5    missing                Canada
# 42653       5    missing          South Africa
# 42654       4    missing         United States
# 42655       4    missing        United Kingdom
#
# [42656 rows x 3 columns]
